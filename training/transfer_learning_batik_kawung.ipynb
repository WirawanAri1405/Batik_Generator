# %%
import os
import shutil

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install lightweight-gan pytorch_fid
# Out:
# Requirement already satisfied: lightweight-gan in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Collecting pytorch_fid
#   Downloading pytorch_fid-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: adabelief-pytorch in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (0.2.1)
# Requirement already satisfied: einops>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (0.8.1)
# Requirement already satisfied: fire in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (0.7.1)
# Requirement already satisfied: kornia>=0.5.4 in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (0.8.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (11.3.0)
# Requirement already satisfied: retry in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (0.9.2)
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (2.9.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (0.24.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from lightweight-gan) (4.67.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pytorch_fid) (1.16.3)
# Requirement already satisfied: kornia_rs>=0.1.9 in /usr/local/lib/python3.12/dist-packages (from kornia>=0.5.4->lightweight-gan) (0.1.10)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kornia>=0.5.4->lightweight-gan) (25.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->lightweight-gan) (3.5.0)
# Requirement already satisfied: colorama>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from adabelief-pytorch->lightweight-gan) (0.4.6)
# Requirement already satisfied: tabulate>=0.7 in /usr/local/lib/python3.12/dist-packages (from adabelief-pytorch->lightweight-gan) (0.9.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->lightweight-gan) (3.2.0)
# Requirement already satisfied: decorator>=3.4.2 in /usr/local/lib/python3.12/dist-packages (from retry->lightweight-gan) (4.4.2)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /usr/local/lib/python3.12/dist-packages (from retry->lightweight-gan) (1.11.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2->lightweight-gan) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.2->lightweight-gan) (3.0.3)
# Downloading pytorch_fid-0.3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pytorch_fid
# Successfully installed pytorch_fid-0.3.0

# %%
import os
from PIL import Image
from tqdm import tqdm
from collections import Counter
import matplotlib.pyplot as plt

# --- GANTI PATH INI ---
DATASET_FOLDER = "/content/drive/MyDrive/FP AI LANJUT/BATIK_GENERATOR/dataset/dataset_256/batik_kawung"
# ----------------------

def simple_eda(folder_path):
    print(f"Menganalisis dataset di: {folder_path} ...")

    valid_extensions = {'.jpg', '.jpeg', '.png', '.webp', '.bmp'}
    files = [f for f in os.listdir(folder_path) if os.path.splitext(f)[1].lower() in valid_extensions]

    if not files:
        print("Folder kosong atau tidak ada gambar!")
        return

    modes = []
    sizes = []
    corrupt_files = []

    for filename in tqdm(files):
        filepath = os.path.join(folder_path, filename)
        try:
            with Image.open(filepath) as img:
                # Cek Mode Warna (RGB, L, RGBA, CMYK, dll)
                modes.append(img.mode)
                # Cek Ukuran
                sizes.append(img.size) # (width, height)
        except Exception:
            corrupt_files.append(filename)

    # --- LAPORAN ---
    print("\n" + "="*30)
    print("       HASIL ANALISIS")
    print("="*30)
    print(f"Total Gambar Terbaca: {len(modes)}")
    print(f"File Rusak/Corrupt  : {len(corrupt_files)} (Hapus file ini!)")

    print("\n--- 1. Distribusi Channel Warna ---")
    mode_counts = Counter(modes)
    for mode, count in mode_counts.items():
        status = "AMAN" if mode == "RGB" else "BAHAYA (Perlu Convert)"
        print(f"  - {mode:<5} : {count:<5} file -> {status}")

    print("\n--- 2. Distribusi Ukuran (Resolusi) ---")
    widths = [s[0] for s in sizes]
    heights = [s[1] for s in sizes]

    print(f"  - Terkecil : {min(widths)}x{min(heights)} px")
    print(f"  - Terbesar : {max(widths)}x{max(heights)} px")
    print(f"  - Rata-rata: {int(sum(widths)/len(widths))}x{int(sum(heights)/len(heights))} px")

    # Cek Gambar Kekecilan
    too_small = sum(1 for w, h in sizes if w < 256 or h < 256)
    if too_small > 0:
        print(f"\n[!] PERINGATAN: Ada {too_small} gambar di bawah 256px. Hasil mungkin buram.")
    else:
        print("\n[OK] Semua gambar resolusi cukup besar.")

    if corrupt_files:
        print("\n[!] DAFTAR FILE RUSAK:")
        print(corrupt_files)

simple_eda(DATASET_FOLDER)
# Out:
# Menganalisis dataset di: /content/drive/MyDrive/FP AI LANJUT/BATIK_GENERATOR/dataset/dataset_256/batik_kawung ...
# 100%|██████████| 150/150 [00:04<00:00, 34.89it/s]
# ==============================
#        HASIL ANALISIS
# ==============================
# Total Gambar Terbaca: 150
# File Rusak/Corrupt  : 0 (Hapus file ini!)
#
# --- 1. Distribusi Channel Warna ---
#   - RGB   : 150   file -> AMAN
#
# --- 2. Distribusi Ukuran (Resolusi) ---
#   - Terkecil : 256x256 px
#   - Terbesar : 256x256 px
#   - Rata-rata: 256x256 px
#
# [OK] Semua gambar resolusi cukup besar.

# %%
# !lightweight_gan \
    --data "/content/drive/MyDrive/FP AI LANJUT/BATIK_GENERATOR/dataset/dataset_256/batik_kawung" \
    --name "batik_kawung" \
    --results_dir "/content/drive/MyDrive/FP AI LANJUT/BATIK_GENERATOR/results" \
    --models_dir "/content/drive/MyDrive/FP AI LANJUT/BATIK_GENERATOR/models" \
    --load-from 12 \
    --image-size 256 \
    --batch-size 8 \
    --gradient-accumulate-every 2 \
    --disc-output-size 5 \
    --num-train-steps 30050 \
    --save-every 2500 \
    --evaluate-every 1000 \
    --amp \
    --aug-prob 0.20 \
    --aug-types "[translation,color,offset]" \
    --calculate-fid-every 5000 \
    --calculate-fid-num-images 150
# Out:
# loading from version 1.2.1
# batik_kawung</content/drive/MyDrive/FP AI LANJUT/BATIK_GENERATOR/dataset/dataset_256/batik_kawung>: 100% 30000/30050 [00:00<?, ?it/s]
# calculating FID - saving generated:   0% 0/19 [00:00<?, ?it/s]
# calculating FID - saving generated:   5% 1/19 [00:00<00:02,  6.33it/s]
# calculating FID - saving generated:  11% 2/19 [00:00<00:02,  6.38it/s]
# calculating FID - saving generated:  16% 3/19 [00:00<00:02,  6.44it/s]
# calculating FID - saving generated:  21% 4/19 [00:00<00:02,  6.29it/s]
# calculating FID - saving generated:  26% 5/19 [00:00<00:02,  6.38it/s]
# calculating FID - saving generated:  32% 6/19 [00:00<00:02,  6.42it/s]
# calculating FID - saving generated:  37% 7/19 [00:01<00:01,  6.46it/s]
# calculating FID - saving generated:  42% 8/19 [00:01<00:01,  6.47it/s]
# calculating FID - saving generated:  47% 9/19 [00:01<00:01,  6.48it/s]
# calculating FID - saving generated:  53% 10/19 [00:01<00:01,  6.49it/s]
# calculating FID - saving generated:  58% 11/19 [00:01<00:01,  6.50it/s]
# calculating FID - saving generated:  63% 12/19 [00:01<00:01,  6.49it/s]
# calculating FID - saving generated:  68% 13/19 [00:02<00:00,  6.49it/s]
# calculating FID - saving generated:  74% 14/19 [00:02<00:00,  6.49it/s]
# calculating FID - saving generated:  79% 15/19 [00:02<00:00,  6.48it/s]
# calculating FID - saving generated:  84% 16/19 [00:02<00:00,  6.49it/s]
# calculating FID - saving generated:  89% 17/19 [00:02<00:00,  6.50it/s]
# calculating FID - saving generated:  95% 18/19 [00:02<00:00,  6.47it/s]
# calculating FID - saving generated: 100% 19/19 [00:02<00:00,  6.46it/s]
# Warning: batch size is bigger than the data size. Setting batch size to data size
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:01<00:00,  1.37s/it]
# Warning: batch size is bigger than the data size. Setting batch size to data size
#
#   0% 0/1 [00:00<?, ?it/s]
# 100% 1/1 [00:00<00:00,  1.00it/s]
# batik_kawung</content/drive/MyDrive/FP AI LANJUT/BATIK_GENERATOR/dataset/dataset_256/batik_kawung>: 100% 30050/30050 [01:39<00:00,  1.98s/it]G: 0.54 | D: 1.54 | GP: 1.33 | SS: 0.06 | FID: 189.13
# batik_kawung</content/drive/MyDrive/FP AI LANJUT/BATIK_GENERATOR/dataset/dataset_256/batik_kawung>: 100% 30050/30050 [01:40<00:00,  2.00s/it]
