# %%
import os
import shutil

from google.colab import drive
drive.mount('/content/drive')

# !pip install lightweight-gan
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 37.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.9/115.9 kB 11.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 114.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 kB 10.0 MB/s eta 0:00:00
# ...

# %%
! lightweight_gan \
    --data "/content/drive/MyDrive/FP AI LANJUT/dataset" \
    --name "train" \
    --results_dir "/content/drive/MyDrive/FP AI LANJUT/Ai_Asistant/results" \
    --models_dir "/content/drive/MyDrive/FP AI LANJUT/Ai_Asistant/models" \
    --load-from 15 \
    --image-size 256 \
    --batch-size 8 \
    --gradient-accumulate-every 1 \
    --disc-output-size 5 \
    --num-train-steps 22000 \
    --save-every 1000 \
    --evaluate-every 250 \
    --amp \
    --aug-prob 0.20 \
    --aug-types "[translation,color,offset]"
# Out:
# loading from version 1.2.1
# train</content/drive/MyDrive/FP AI LANJUT/dataset>:  68% 15050/22000 [00:41<1:36:00,  1.21it/s]G: 0.76 | D: 2.19 | GP: 0.67 | SS: 0.05
# train</content/drive/MyDrive/FP AI LANJUT/dataset>:  69% 15100/22000 [01:08<1:18:17,  1.47it/s]G: 1.12 | D: 0.07 | GP: 0.71 | SS: 0.02
# train</content/drive/MyDrive/FP AI LANJUT/dataset>:  69% 15150/22000 [01:38<1:15:13,  1.52it/s]G: 0.79 | D: 0.33 | GP: 0.40 | SS: 0.03
# train</content/drive/MyDrive/FP AI LANJUT/dataset>:  69% 15200/22000 [02:05<1:10:53,  1.60it/s]G: 1.68 | D: 0.08 | GP: 0.59 | SS: 0.02
# train</content/drive/MyDrive/FP AI LANJUT/dataset>:  69% 15250/22000 [02:36<1:10:14,  1.60it/s]G: 0.67 | D: 0.24 | GP: 0.44 | SS: 0.03
# train</content/drive/MyDrive/FP AI LANJUT/dataset>:  70% 15300/22000 [03:06<1:09:20,  1.61it/s]G: 1.17 | D: 0.04 | GP: 0.64 | SS: 0.02
# train</content/drive/MyDrive/FP AI LANJUT/dataset>:  70% 15350/22000 [03:37<1:08:47,  1.61it/s]G: 1.14 | D: 0.16 | GP: 0.75 | SS: 0.03
# ...
